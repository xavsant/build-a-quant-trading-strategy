# %% [markdown]
# ## Strategy Development

# %% [markdown]
# ### Strategy Types

# %%
# 1 Maker strategies => they are providing liquidity => adding liquidity to a market and aim to be compensated for it
# 2 Taker strategies => they take away liquidity => market orders that consume liquidity => what we are going to focus on

# %%
# Key Questions for our taking strategy

# 1. Entry/Exit
# 2. Trade Sizing
# 3. Leverage

# %%
## the key goal is we want to create a strategy that maximises profits from the model's statistical edge

# %% [markdown]
# ### Import Libraries

# %%
# Data and analysis libraries
import polars as pl                         # Fast dataframes for financial data
import numpy as np                          # Numerical computing library
from datetime import datetime, timedelta    # Date and time operations
import random


# Machine learning libraries  
import torch                                # PyTorch framework
import torch.nn as nn                       # Neural network modules
import torch.optim as optim                 # Optimization algorithms
import research                             # Model building and training utilities


# Visualization and 
import altair as alt                        # Interactive visualization library

# data sources
import data.binance                              # Binance market data utilities

# %% [markdown]
# ###  Load Model

# %%
import models
model = models.LinearModel(3)
model.load_state_dict(torch.load('model_weights/model_weights.pth', weights_only=True))
model.eval()
# Out:
# LinearModel(
#   (linear): Linear(in_features=3, out_features=1, bias=True)
# )

# %% [markdown]
# ### Model Parameters

# %%
research.print_model_params(model)
# Out:
# linear.weight:
# [[-0.11644533 -0.101147    0.06086021]]
# linear.bias:
# [0.00109754]

# %% [markdown]
# ### What is Mean Reversion?

# %%
series = [-0.014000, 0.011399, -0.012212, 0.01997, -0.01442, 0.01227]
mu = np.mean(series)
mean_reversion_df = pl.DataFrame({'log_return': series, 'mean': mu})
mean_reversion_df
# Out:
# shape: (6, 2)
# ┌────────────┬──────────┐
# │ log_return ┆ mean     │
# │ ---        ┆ ---      │
# │ f64        ┆ f64      │
# ╞════════════╪══════════╡
# │ -0.014     ┆ 0.000501 │
# │ 0.011399   ┆ 0.000501 │
# │ -0.012212  ┆ 0.000501 │
# │ 0.01997    ┆ 0.000501 │
# │ -0.01442   ┆ 0.000501 │
# │ 0.01227    ┆ 0.000501 │
# └────────────┴──────────┘

# %%
research.plot_multiple_lines(mean_reversion_df, ['log_return','mean'], 'Mean Reversion')

# %% [markdown]
# ### Interpretability - Linear Model

# %%
def linear_model(x):
    w, b = -0.09911217, 0.00059838
    return w * x + b

linear_model(-0.015)
# Out:
# 0.00208506255

# %%
linear_model(0.02)
# Out:
# -0.0013838634

# %%
linear_model(0.000002)
# Out:
# 0.00059818177566

# %%
linear_model(0.0)
# Out:
# 0.00059838

# %% [markdown]
# ### Interpretability - Non Linear Model

# %%
def nn_model(x):
    x = torch.tensor([x])
    W = torch.tensor([0.08035, -0.01478, -0.03523,  0.06777,  0.03789,  0.0013991, -0.13303,  0.8045])
    b = torch.tensor([0.16421])
    return torch.tanh(torch.sum(x * W) + b)

nn_model(-0.015)
# Out:
# tensor([0.1509])

# %%
# no interability
nn_model(0.02)
# Out:
# tensor([0.1785])

# %%
nn_model(0.0)
# Out:
# tensor([0.1627])

# %%
# not disparaging neural networks as my background is neural networks 
# but for trading, neural networks can increase your expected value but at the expense of complexity
# I tend to favour linear models because they are interpretible, are not sensitive to noise, less prone to overfit (generalization)

# %% [markdown]
# ## Strategy Development!

# %% [markdown]
# ### Load Time Series

# %%
sym = 'BTCUSDT'
time_interval = '12h'

ts = pl.read_csv(f"data/{sym}_{time_interval}_ohlc.csv", try_parse_dates=True).sort('datetime')
ts
# Out:
# shape: (692, 5)
# ┌─────────────────────┬──────────┬──────────┬──────────┬──────────┐
# │ datetime            ┆ open     ┆ high     ┆ low      ┆ close    │
# │ ---                 ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ datetime[μs]        ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞═════════════════════╪══════════╪══════════╪══════════╪══════════╡
# │ 2024-10-29 00:00:00 ┆ 69939.9  ┆ 71607.0  ┆ 69733.0  ┆ 71440.1  │
# │ 2024-10-29 12:00:00 ┆ 71440.0  ┆ 73660.0  ┆ 70900.0  ┆ 72739.5  │
# │ 2024-10-30 00:00:00 ┆ 72739.5  ┆ 72797.4  ┆ 71931.1  ┆ 71995.0  │
# │ 2024-10-30 12:00:00 ┆ 71994.9  ┆ 72984.9  ┆ 71444.2  ┆ 72349.0  │
# │ 2024-10-31 00:00:00 ┆ 72349.0  ┆ 72720.3  ┆ 72030.5  ┆ 72213.3  │
# │ …                   ┆ …        ┆ …        ┆ …        ┆ …        │
# │ 2025-10-07 12:00:00 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ 121286.5 │
# │ 2025-10-08 00:00:00 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ 122825.7 │
# │ 2025-10-08 12:00:00 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ 123237.5 │
# │ 2025-10-09 00:00:00 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ 122672.9 │
# │ 2025-10-09 12:00:00 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ 121579.3 │
# └─────────────────────┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# ### Add Target and Features

# %%
sym = 'BTCUSDT'
forecast_horizon = 1
ts = research.add_log_return_features(ts, 'close', forecast_horizon, max_no_lags=3)
ts
# Out:
# shape: (692, 9)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ high     ┆ low      ┆ … ┆ close_log_ ┆ close_log ┆ close_log ┆ close_log │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ return     ┆ _return_l ┆ _return_l ┆ _return_l │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ ---        ┆ ag_1      ┆ ag_2      ┆ ag_3      │
# │ s]         ┆          ┆          ┆          ┆   ┆ f64        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆          ┆          ┆          ┆   ┆            ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2024-10-29 ┆ 69939.9  ┆ 71607.0  ┆ 69733.0  ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2024-10-29 ┆ 71440.0  ┆ 73660.0  ┆ 70900.0  ┆ … ┆ 0.018025   ┆ null      ┆ null      ┆ null      │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2024-10-30 ┆ 72739.5  ┆ 72797.4  ┆ 71931.1  ┆ … ┆ -0.010288  ┆ 0.018025  ┆ null      ┆ null      │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2024-10-30 ┆ 71994.9  ┆ 72984.9  ┆ 71444.2  ┆ … ┆ 0.004905   ┆ -0.010288 ┆ 0.018025  ┆ null      │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2024-10-31 ┆ 72349.0  ┆ 72720.3  ┆ 72030.5  ┆ … ┆ -0.001877  ┆ 0.004905  ┆ -0.010288 ┆ 0.018025  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ … ┆ -0.025324  ┆ -0.001858 ┆ 0.003757  ┆ 0.005933  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ … ┆ 0.012611   ┆ -0.025324 ┆ -0.001858 ┆ 0.003757  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ … ┆ 0.003347   ┆ 0.012611  ┆ -0.025324 ┆ -0.001858 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ … ┆ -0.004592  ┆ 0.003347  ┆ 0.012611  ┆ -0.025324 │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ … ┆ -0.008955  ┆ -0.004592 ┆ 0.003347  ┆ 0.012611  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Time Split

# %%
test_size = 0.25
_, trades = research.timeseries_split(ts, test_size)
trades
# Out:
# shape: (173, 9)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ high     ┆ low      ┆ … ┆ close_log_ ┆ close_log ┆ close_log ┆ close_log │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ return     ┆ _return_l ┆ _return_l ┆ _return_l │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ ---        ┆ ag_1      ┆ ag_2      ┆ ag_3      │
# │ s]         ┆          ┆          ┆          ┆   ┆ f64        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆          ┆          ┆          ┆   ┆            ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 118499.8 ┆ 115678.1 ┆ … ┆ 0.005349   ┆ -0.022844 ┆ -0.013743 ┆ 0.020259  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 119299.9 ┆ 117017.1 ┆ … ┆ 0.008597   ┆ 0.005349  ┆ -0.022844 ┆ -0.013743 │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 120100.0 ┆ 118156.0 ┆ … ┆ -0.001385  ┆ 0.008597  ┆ 0.005349  ┆ -0.022844 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 119216.4 ┆ 117663.6 ┆ … ┆ -0.005257  ┆ -0.001385 ┆ 0.008597  ┆ 0.005349  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 120951.5 ┆ 117412.8 ┆ … ┆ 0.010185   ┆ -0.005257 ┆ -0.001385 ┆ 0.008597  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ … ┆ -0.025324  ┆ -0.001858 ┆ 0.003757  ┆ 0.005933  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ … ┆ 0.012611   ┆ -0.025324 ┆ -0.001858 ┆ 0.003757  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ … ┆ 0.003347   ┆ 0.012611  ┆ -0.025324 ┆ -0.001858 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ … ┆ -0.004592  ┆ 0.003347  ┆ 0.012611  ┆ -0.025324 │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ … ┆ -0.008955  ┆ -0.004592 ┆ 0.003347  ┆ 0.012611  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Strategy Decision # 1: Entry / Exit Signal

# %%
# q1: when do we get in? entry signal
# q2: when do we get out? exit signal

# %%
# 1. Time Based 
# 2. Predicate Based

# %%
# predicate based => e.g. we only want to trade if our y_hat is above or below a certain threshold

# %%
# time based => each row represents a roundtrip trade. trade to open position at start of interval, trade to close the position at end of interval. each row = 2 trades.

# %%
trades
# Out:
# shape: (173, 9)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ high     ┆ low      ┆ … ┆ close_log_ ┆ close_log ┆ close_log ┆ close_log │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ return     ┆ _return_l ┆ _return_l ┆ _return_l │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ ---        ┆ ag_1      ┆ ag_2      ┆ ag_3      │
# │ s]         ┆          ┆          ┆          ┆   ┆ f64        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆          ┆          ┆          ┆   ┆            ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 118499.8 ┆ 115678.1 ┆ … ┆ 0.005349   ┆ -0.022844 ┆ -0.013743 ┆ 0.020259  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 119299.9 ┆ 117017.1 ┆ … ┆ 0.008597   ┆ 0.005349  ┆ -0.022844 ┆ -0.013743 │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 120100.0 ┆ 118156.0 ┆ … ┆ -0.001385  ┆ 0.008597  ┆ 0.005349  ┆ -0.022844 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 119216.4 ┆ 117663.6 ┆ … ┆ -0.005257  ┆ -0.001385 ┆ 0.008597  ┆ 0.005349  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 120951.5 ┆ 117412.8 ┆ … ┆ 0.010185   ┆ -0.005257 ┆ -0.001385 ┆ 0.008597  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ … ┆ -0.025324  ┆ -0.001858 ┆ 0.003757  ┆ 0.005933  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ … ┆ 0.012611   ┆ -0.025324 ┆ -0.001858 ┆ 0.003757  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ … ┆ 0.003347   ┆ 0.012611  ┆ -0.025324 ┆ -0.001858 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ … ┆ -0.004592  ┆ 0.003347  ┆ 0.012611  ┆ -0.025324 │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ … ┆ -0.008955  ┆ -0.004592 ┆ 0.003347  ┆ 0.012611  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Add Model's Predictions

# %%
target = 'close_log_return'
features = [f'{target}_lag_1',f'{target}_lag_2',f'{target}_lag_3']
trades = research.add_model_predictions(trades, model, features)
trades
# Out:
# shape: (173, 10)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ high     ┆ low      ┆ … ┆ close_log_ ┆ close_log ┆ close_log ┆ y_hat     │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ return_lag ┆ _return_l ┆ _return_l ┆ ---       │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ _1         ┆ ag_2      ┆ ag_3      ┆ f32       │
# │ s]         ┆          ┆          ┆          ┆   ┆ ---        ┆ ---       ┆ ---       ┆           │
# │            ┆          ┆          ┆          ┆   ┆ f64        ┆ f64       ┆ f64       ┆           │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 118499.8 ┆ 115678.1 ┆ … ┆ -0.022844  ┆ -0.013743 ┆ 0.020259  ┆ 0.006381  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 119299.9 ┆ 117017.1 ┆ … ┆ 0.005349   ┆ -0.022844 ┆ -0.013743 ┆ 0.001949  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 120100.0 ┆ 118156.0 ┆ … ┆ 0.008597   ┆ 0.005349  ┆ -0.022844 ┆ -0.001835 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 119216.4 ┆ 117663.6 ┆ … ┆ -0.001385  ┆ 0.008597  ┆ 0.005349  ┆ 0.000715  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 120951.5 ┆ 117412.8 ┆ … ┆ -0.005257  ┆ -0.001385 ┆ 0.008597  ┆ 0.002373  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ … ┆ -0.001858  ┆ 0.003757  ┆ 0.005933  ┆ 0.001295  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ … ┆ -0.025324  ┆ -0.001858 ┆ 0.003757  ┆ 0.004463  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ … ┆ 0.012611   ┆ -0.025324 ┆ -0.001858 ┆ 0.002077  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ … ┆ 0.003347   ┆ 0.012611  ┆ -0.025324 ┆ -0.002109 │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ … ┆ -0.004592  ┆ 0.003347  ┆ 0.012611  ┆ 0.002061  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Add Directional Signal

# %%
trades = trades.with_columns(pl.col('y_hat').sign().alias('dir_signal'))
trades
# Out:
# shape: (173, 11)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ high     ┆ low      ┆ … ┆ close_log_ ┆ close_log ┆ y_hat     ┆ dir_signa │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ return_lag ┆ _return_l ┆ ---       ┆ l         │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ _2         ┆ ag_3      ┆ f32       ┆ ---       │
# │ s]         ┆          ┆          ┆          ┆   ┆ ---        ┆ ---       ┆           ┆ f32       │
# │            ┆          ┆          ┆          ┆   ┆ f64        ┆ f64       ┆           ┆           │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 118499.8 ┆ 115678.1 ┆ … ┆ -0.013743  ┆ 0.020259  ┆ 0.006381  ┆ 1.0       │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 119299.9 ┆ 117017.1 ┆ … ┆ -0.022844  ┆ -0.013743 ┆ 0.001949  ┆ 1.0       │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 120100.0 ┆ 118156.0 ┆ … ┆ 0.005349   ┆ -0.022844 ┆ -0.001835 ┆ -1.0      │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 119216.4 ┆ 117663.6 ┆ … ┆ 0.008597   ┆ 0.005349  ┆ 0.000715  ┆ 1.0       │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 120951.5 ┆ 117412.8 ┆ … ┆ -0.001385  ┆ 0.008597  ┆ 0.002373  ┆ 1.0       │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ … ┆ 0.003757   ┆ 0.005933  ┆ 0.001295  ┆ 1.0       │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ … ┆ -0.001858  ┆ 0.003757  ┆ 0.004463  ┆ 1.0       │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ … ┆ -0.025324  ┆ -0.001858 ┆ 0.002077  ┆ 1.0       │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ … ┆ 0.012611   ┆ -0.025324 ┆ -0.002109 ┆ -1.0      │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ … ┆ 0.003347   ┆ 0.012611  ┆ 0.002061  ┆ 1.0       │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Calculate Trade Log Return

# %%
trades = trades.with_columns((pl.col('close_log_return')*pl.col('dir_signal')).alias('trade_log_return'))
trades
# Out:
# shape: (173, 12)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ high     ┆ low      ┆ … ┆ close_log_ ┆ y_hat     ┆ dir_signa ┆ trade_log │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ return_lag ┆ ---       ┆ l         ┆ _return   │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ _3         ┆ f32       ┆ ---       ┆ ---       │
# │ s]         ┆          ┆          ┆          ┆   ┆ ---        ┆           ┆ f32       ┆ f64       │
# │            ┆          ┆          ┆          ┆   ┆ f64        ┆           ┆           ┆           │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 118499.8 ┆ 115678.1 ┆ … ┆ 0.020259   ┆ 0.006381  ┆ 1.0       ┆ 0.005349  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 119299.9 ┆ 117017.1 ┆ … ┆ -0.013743  ┆ 0.001949  ┆ 1.0       ┆ 0.008597  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 120100.0 ┆ 118156.0 ┆ … ┆ -0.022844  ┆ -0.001835 ┆ -1.0      ┆ 0.001385  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 119216.4 ┆ 117663.6 ┆ … ┆ 0.005349   ┆ 0.000715  ┆ 1.0       ┆ -0.005257 │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 120951.5 ┆ 117412.8 ┆ … ┆ 0.008597   ┆ 0.002373  ┆ 1.0       ┆ 0.010185  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ … ┆ 0.005933   ┆ 0.001295  ┆ 1.0       ┆ -0.025324 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ … ┆ 0.003757   ┆ 0.004463  ┆ 1.0       ┆ 0.012611  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ … ┆ -0.001858  ┆ 0.002077  ┆ 1.0       ┆ 0.003347  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ … ┆ -0.025324  ┆ -0.002109 ┆ -1.0      ┆ 0.004592  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ … ┆ 0.012611   ┆ 0.002061  ┆ 1.0       ┆ -0.008955 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Calculate Cumulative Trade Log Return

# %%
trades = trades.with_columns(pl.col('trade_log_return').cum_sum().alias('cum_trade_log_return'))
trades
# Out:
# shape: (173, 13)
# ┌────────────┬──────────┬──────────┬──────────┬───┬───────────┬────────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ high     ┆ low      ┆ … ┆ y_hat     ┆ dir_signal ┆ trade_log ┆ cum_trade │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ---       ┆ ---        ┆ _return   ┆ _log_retu │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ f32       ┆ f32        ┆ ---       ┆ rn        │
# │ s]         ┆          ┆          ┆          ┆   ┆           ┆            ┆ f64       ┆ ---       │
# │            ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆ f64       │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪═══════════╪════════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 118499.8 ┆ 115678.1 ┆ … ┆ 0.006381  ┆ 1.0        ┆ 0.005349  ┆ 0.005349  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 119299.9 ┆ 117017.1 ┆ … ┆ 0.001949  ┆ 1.0        ┆ 0.008597  ┆ 0.013946  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 120100.0 ┆ 118156.0 ┆ … ┆ -0.001835 ┆ -1.0       ┆ 0.001385  ┆ 0.015332  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 119216.4 ┆ 117663.6 ┆ … ┆ 0.000715  ┆ 1.0        ┆ -0.005257 ┆ 0.010075  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 120951.5 ┆ 117412.8 ┆ … ┆ 0.002373  ┆ 1.0        ┆ 0.010185  ┆ 0.02026   │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …         ┆ …          ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ … ┆ 0.001295  ┆ 1.0        ┆ -0.025324 ┆ 0.147263  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ … ┆ 0.004463  ┆ 1.0        ┆ 0.012611  ┆ 0.159874  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ … ┆ 0.002077  ┆ 1.0        ┆ 0.003347  ┆ 0.163221  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ … ┆ -0.002109 ┆ -1.0       ┆ 0.004592  ┆ 0.167813  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ … ┆ 0.002061  ┆ 1.0        ┆ -0.008955 ┆ 0.158858  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆           ┆            ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴───────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# ### Display Equity Curve (Log Space)

# %%
research.plot_column(trades, 'cum_trade_log_return')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Key Strategy Decision #2: Trade Sizing

# %%
# 1. Constant Trade Size
# 2. Compounding Trade Size

# %%
capital = 100
ratio = 1.0 # you could experiment with different ratios like kelly criterion
trade_value = ratio * capital

# entry trade value and exit trade value
trades = trades.with_columns(
    pl.lit(trade_value).alias('entry_trade_value'),
    (trade_value * pl.col('trade_log_return').exp()).alias('exit_trade_value'),
    (trade_value / pl.col('open')).alias('trade_qty'),
).with_columns(
    (pl.col('trade_qty') * pl.col('dir_signal')).alias('signed_trade_qty'),
)

trades.select('datetime','open','close', 'trade_log_return','y_hat','entry_trade_value','exit_trade_value', 'signed_trade_qty')
# Out:
# shape: (173, 8)
# ┌────────────┬──────────┬──────────┬────────────┬───────────┬────────────┬────────────┬────────────┐
# │ datetime   ┆ open     ┆ close    ┆ trade_log_ ┆ y_hat     ┆ entry_trad ┆ exit_trade ┆ signed_tra │
# │ ---        ┆ ---      ┆ ---      ┆ return     ┆ ---       ┆ e_value    ┆ _value     ┆ de_qty     │
# │ datetime[μ ┆ f64      ┆ f64      ┆ ---        ┆ f32       ┆ ---        ┆ ---        ┆ ---        │
# │ s]         ┆          ┆          ┆ f64        ┆           ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪══════════╪══════════╪════════════╪═══════════╪════════════╪════════════╪════════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 117738.5 ┆ 0.005349   ┆ 0.006381  ┆ 100.0      ┆ 100.536332 ┆ 0.000854   │
# │ 12:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ 2025-07-16 ┆ 117738.6 ┆ 118755.1 ┆ 0.008597   ┆ 0.001949  ┆ 100.0      ┆ 100.863439 ┆ 0.000849   │
# │ 00:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ 2025-07-16 ┆ 118755.1 ┆ 118590.7 ┆ 0.001385   ┆ -0.001835 ┆ 100.0      ┆ 100.138628 ┆ -0.000842  │
# │ 12:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ 2025-07-17 ┆ 118590.7 ┆ 117968.9 ┆ -0.005257  ┆ 0.000715  ┆ 100.0      ┆ 99.475676  ┆ 0.000843   │
# │ 00:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ 2025-07-17 ┆ 117968.8 ┆ 119176.6 ┆ 0.010185   ┆ 0.002373  ┆ 100.0      ┆ 101.023744 ┆ 0.000848   │
# │ 12:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ …          ┆ …        ┆ …        ┆ …          ┆ …         ┆ …          ┆ …          ┆ …          │
# │ 2025-10-07 ┆ 124397.1 ┆ 121286.5 ┆ -0.025324  ┆ 0.001295  ┆ 100.0      ┆ 97.499381  ┆ 0.000804   │
# │ 12:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ 2025-10-08 ┆ 121286.6 ┆ 122825.7 ┆ 0.012611   ┆ 0.004463  ┆ 100.0      ┆ 101.269061 ┆ 0.000824   │
# │ 00:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ 2025-10-08 ┆ 122825.8 ┆ 123237.5 ┆ 0.003347   ┆ 0.002077  ┆ 100.0      ┆ 100.335272 ┆ 0.000814   │
# │ 12:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ 2025-10-09 ┆ 123237.4 ┆ 122672.9 ┆ 0.004592   ┆ -0.002109 ┆ 100.0      ┆ 100.460248 ┆ -0.000811  │
# │ 00:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# │ 2025-10-09 ┆ 122673.0 ┆ 121579.3 ┆ -0.008955  ┆ 0.002061  ┆ 100.0      ┆ 99.108524  ┆ 0.000815   │
# │ 12:00:00   ┆          ┆          ┆            ┆           ┆            ┆            ┆            │
# └────────────┴──────────┴──────────┴────────────┴───────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# ### Add Trade Gross PnL

# %%
trades = trades.with_columns((pl.col('exit_trade_value') - pl.col('entry_trade_value')).alias('trade_gross_pnl'))
trades.select('datetime','open','close', 'trade_log_return','y_hat','entry_trade_value','exit_trade_value', 'signed_trade_qty', 'trade_gross_pnl')
# Out:
# shape: (173, 9)
# ┌────────────┬──────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ close    ┆ trade_log ┆ … ┆ entry_tra ┆ exit_trad ┆ signed_tr ┆ trade_gro │
# │ ---        ┆ ---      ┆ ---      ┆ _return   ┆   ┆ de_value  ┆ e_value   ┆ ade_qty   ┆ ss_pnl    │
# │ datetime[μ ┆ f64      ┆ f64      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ s]         ┆          ┆          ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 117738.5 ┆ 0.005349  ┆ … ┆ 100.0     ┆ 100.53633 ┆ 0.000854  ┆ 0.536332  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 2         ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 118755.1 ┆ 0.008597  ┆ … ┆ 100.0     ┆ 100.86343 ┆ 0.000849  ┆ 0.863439  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 9         ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 118590.7 ┆ 0.001385  ┆ … ┆ 100.0     ┆ 100.13862 ┆ -0.000842 ┆ 0.138628  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 8         ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 117968.9 ┆ -0.005257 ┆ … ┆ 100.0     ┆ 99.475676 ┆ 0.000843  ┆ -0.524324 │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 119176.6 ┆ 0.010185  ┆ … ┆ 100.0     ┆ 101.02374 ┆ 0.000848  ┆ 1.023744  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 4         ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 121286.5 ┆ -0.025324 ┆ … ┆ 100.0     ┆ 97.499381 ┆ 0.000804  ┆ -2.500619 │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 122825.7 ┆ 0.012611  ┆ … ┆ 100.0     ┆ 101.26906 ┆ 0.000824  ┆ 1.269061  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 1         ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 123237.5 ┆ 0.003347  ┆ … ┆ 100.0     ┆ 100.33527 ┆ 0.000814  ┆ 0.335272  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 2         ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 122672.9 ┆ 0.004592  ┆ … ┆ 100.0     ┆ 100.46024 ┆ -0.000811 ┆ 0.460248  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 8         ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 121579.3 ┆ -0.008955 ┆ … ┆ 100.0     ┆ 99.108524 ┆ 0.000815  ┆ -0.891476 │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Add Transaction Fees

# %%
taker_fee = data.binance.TAKER_FEE
maker_fee = data.binance.MAKER_FEE

trades = trades.with_columns(
    (pl.col('entry_trade_value') * taker_fee + pl.col('exit_trade_value') * taker_fee).alias('taker_fee'),
    (pl.col('entry_trade_value') * maker_fee + pl.col('exit_trade_value') * maker_fee).alias('maker_fee')
)

trades.select('datetime','open','close', 'trade_log_return','y_hat','entry_trade_value','exit_trade_value', 'signed_trade_qty', 'trade_gross_pnl','maker_fee','taker_fee')
# Out:
# shape: (173, 11)
# ┌────────────┬──────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ close    ┆ trade_log ┆ … ┆ signed_tr ┆ trade_gro ┆ maker_fee ┆ taker_fee │
# │ ---        ┆ ---      ┆ ---      ┆ _return   ┆   ┆ ade_qty   ┆ ss_pnl    ┆ ---       ┆ ---       │
# │ datetime[μ ┆ f64      ┆ f64      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ f64       ┆ f64       │
# │ s]         ┆          ┆          ┆ f64       ┆   ┆ f64       ┆ f64       ┆           ┆           │
# ╞════════════╪══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 117738.5 ┆ 0.005349  ┆ … ┆ 0.000854  ┆ 0.536332  ┆ 0.040107  ┆ 0.060161  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 118755.1 ┆ 0.008597  ┆ … ┆ 0.000849  ┆ 0.863439  ┆ 0.040173  ┆ 0.060259  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 118590.7 ┆ 0.001385  ┆ … ┆ -0.000842 ┆ 0.138628  ┆ 0.040028  ┆ 0.060042  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 117968.9 ┆ -0.005257 ┆ … ┆ 0.000843  ┆ -0.524324 ┆ 0.039895  ┆ 0.059843  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 119176.6 ┆ 0.010185  ┆ … ┆ 0.000848  ┆ 1.023744  ┆ 0.040205  ┆ 0.060307  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 121286.5 ┆ -0.025324 ┆ … ┆ 0.000804  ┆ -2.500619 ┆ 0.0395    ┆ 0.05925   │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 122825.7 ┆ 0.012611  ┆ … ┆ 0.000824  ┆ 1.269061  ┆ 0.040254  ┆ 0.060381  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 123237.5 ┆ 0.003347  ┆ … ┆ 0.000814  ┆ 0.335272  ┆ 0.040067  ┆ 0.060101  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 122672.9 ┆ 0.004592  ┆ … ┆ -0.000811 ┆ 0.460248  ┆ 0.040092  ┆ 0.060138  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 121579.3 ┆ -0.008955 ┆ … ┆ 0.000815  ┆ -0.891476 ┆ 0.039822  ┆ 0.059733  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Calculate Trade Net PnL

# %%
trades = trades.with_columns(
    (pl.col('trade_gross_pnl')-pl.col('taker_fee')).alias('trade_net_taker_pnl'),
    (pl.col('trade_gross_pnl')-pl.col('maker_fee')).alias('trade_net_maker_pnl'),
)

trades.select('datetime','open','close', 'trade_log_return','y_hat','entry_trade_value','exit_trade_value', 'signed_trade_qty', 'trade_gross_pnl','trade_net_taker_pnl','trade_net_maker_pnl')
# Out:
# shape: (173, 11)
# ┌────────────┬──────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ close    ┆ trade_log ┆ … ┆ signed_tr ┆ trade_gro ┆ trade_net ┆ trade_net │
# │ ---        ┆ ---      ┆ ---      ┆ _return   ┆   ┆ ade_qty   ┆ ss_pnl    ┆ _taker_pn ┆ _maker_pn │
# │ datetime[μ ┆ f64      ┆ f64      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ l         ┆ l         │
# │ s]         ┆          ┆          ┆ f64       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ ---       │
# │            ┆          ┆          ┆           ┆   ┆           ┆           ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 117738.5 ┆ 0.005349  ┆ … ┆ 0.000854  ┆ 0.536332  ┆ 0.476171  ┆ 0.496224  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 118755.1 ┆ 0.008597  ┆ … ┆ 0.000849  ┆ 0.863439  ┆ 0.80318   ┆ 0.823266  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 118590.7 ┆ 0.001385  ┆ … ┆ -0.000842 ┆ 0.138628  ┆ 0.078586  ┆ 0.0986    │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 117968.9 ┆ -0.005257 ┆ … ┆ 0.000843  ┆ -0.524324 ┆ -0.584167 ┆ -0.56422  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 119176.6 ┆ 0.010185  ┆ … ┆ 0.000848  ┆ 1.023744  ┆ 0.963437  ┆ 0.98354   │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 121286.5 ┆ -0.025324 ┆ … ┆ 0.000804  ┆ -2.500619 ┆ -2.559869 ┆ -2.540119 │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 122825.7 ┆ 0.012611  ┆ … ┆ 0.000824  ┆ 1.269061  ┆ 1.208681  ┆ 1.228807  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 123237.5 ┆ 0.003347  ┆ … ┆ 0.000814  ┆ 0.335272  ┆ 0.275171  ┆ 0.295205  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 122672.9 ┆ 0.004592  ┆ … ┆ -0.000811 ┆ 0.460248  ┆ 0.40011   ┆ 0.420156  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 121579.3 ┆ -0.008955 ┆ … ┆ 0.000815  ┆ -0.891476 ┆ -0.951209 ┆ -0.931298 │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Display Equity Curves for Constant Sizing

# %%
def equity_curve(capital, col_name, suffix):
    return (capital + (pl.col(col_name).cum_sum())).alias(f'equity_curve_{suffix}')

trades = trades.with_columns(
    equity_curve(capital, 'trade_net_taker_pnl', 'taker'),
    equity_curve(capital, 'trade_net_maker_pnl', 'maker'),
    equity_curve(capital, 'trade_gross_pnl', 'gross'),
)
trades.select('datetime','equity_curve_gross','equity_curve_taker','equity_curve_maker')
# Out:
# shape: (173, 4)
# ┌─────────────────────┬────────────────────┬────────────────────┬────────────────────┐
# │ datetime            ┆ equity_curve_gross ┆ equity_curve_taker ┆ equity_curve_maker │
# │ ---                 ┆ ---                ┆ ---                ┆ ---                │
# │ datetime[μs]        ┆ f64                ┆ f64                ┆ f64                │
# ╞═════════════════════╪════════════════════╪════════════════════╪════════════════════╡
# │ 2025-07-15 12:00:00 ┆ 100.536332         ┆ 100.476171         ┆ 100.496224         │
# │ 2025-07-16 00:00:00 ┆ 101.39977          ┆ 101.27935          ┆ 101.31949          │
# │ 2025-07-16 12:00:00 ┆ 101.538398         ┆ 101.357937         ┆ 101.418091         │
# │ 2025-07-17 00:00:00 ┆ 101.014074         ┆ 100.77377          ┆ 100.853871         │
# │ 2025-07-17 12:00:00 ┆ 102.037818         ┆ 101.737207         ┆ 101.837411         │
# │ …                   ┆ …                  ┆ …                  ┆ …                  │
# │ 2025-10-07 12:00:00 ┆ 115.603842         ┆ 105.459161         ┆ 108.840721         │
# │ 2025-10-08 00:00:00 ┆ 116.872903         ┆ 106.667841         ┆ 110.069529         │
# │ 2025-10-08 12:00:00 ┆ 117.208175         ┆ 106.943013         ┆ 110.364733         │
# │ 2025-10-09 00:00:00 ┆ 117.668423         ┆ 107.343123         ┆ 110.78489          │
# │ 2025-10-09 12:00:00 ┆ 116.776947         ┆ 106.391914         ┆ 109.853592         │
# └─────────────────────┴────────────────────┴────────────────────┴────────────────────┘

# %%
research.plot_static_timeseries(trades, sym, 'equity_curve_taker', time_interval)

# %%
research.plot_static_timeseries(trades, sym, 'equity_curve_maker', time_interval)

# %% [markdown]
# ### Calculate Total Net Return using Constant Sizing

# %%
constant_sizing_net_return = trades['equity_curve_taker'][-1] / capital - 1
constant_sizing_net_return
# Out:
# 0.06391913937476579

# %% [markdown]
# ## experiment with compounding trade sizes

# %%
# 2 => 102 (100 + 2)
# 1 => 103 (100 + 2 + 1)
# -1 => 102 (100 + 2 + 1 - 1)

# %%
log_return_1 = 0.005439
pnl1 = capital * np.exp(log_return_1)
pnl1
# Out:
# np.float64(100.54538182137402)

# %%
log_return_2 = 0.008597
pnl2 = pnl1 * np.exp(log_return_2)
pnl2
# Out:
# np.float64(101.41349671401576)

# %%
log_return_3 = 0.001385
pnl3 = pnl2 * np.exp(log_return_3)
pnl3
# Out:
# np.float64(101.55405171883751)

# %%
((capital * np.exp(log_return_1)) * np.exp(log_return_2)) * np.exp(log_return_3)
# Out:
# np.float64(101.55405171883751)

# %% [markdown]
# ### Time Addivitivity

# %%
capital * np.exp(log_return_1 + log_return_2 + log_return_3)
# Out:
# np.float64(101.55405171883751)

# %% [markdown]
# ### Add Compounding Trade Sizes

# %%
trades = trades.with_columns(
    ((pl.col('cum_trade_log_return').exp()) * capital).shift().fill_null(capital).alias('entry_trade_value'),
    ((pl.col('cum_trade_log_return').exp()) * capital).alias('exit_trade_value'),
).with_columns(
    (pl.col('entry_trade_value') / pl.col('open') * pl.col('dir_signal')).alias('signed_trade_qty'),
    (pl.col('exit_trade_value')-pl.col('entry_trade_value')).alias('trade_gross_pnl'),
)
trades.select('datetime','open','close','trade_log_return','entry_trade_value','exit_trade_value','signed_trade_qty','trade_gross_pnl')
# Out:
# shape: (173, 8)
# ┌────────────┬──────────┬──────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ datetime   ┆ open     ┆ close    ┆ trade_log_ ┆ entry_trad ┆ exit_trade ┆ signed_tra ┆ trade_gro │
# │ ---        ┆ ---      ┆ ---      ┆ return     ┆ e_value    ┆ _value     ┆ de_qty     ┆ ss_pnl    │
# │ datetime[μ ┆ f64      ┆ f64      ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │ s]         ┆          ┆          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞════════════╪══════════╪══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 117738.5 ┆ 0.005349   ┆ 100.0      ┆ 100.536332 ┆ 0.000854   ┆ 0.536332  │
# │ 12:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 118755.1 ┆ 0.008597   ┆ 100.536332 ┆ 101.404401 ┆ 0.000854   ┆ 0.86807   │
# │ 00:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 118590.7 ┆ 0.001385   ┆ 101.404401 ┆ 101.544976 ┆ -0.000854  ┆ 0.140575  │
# │ 12:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 117968.9 ┆ -0.005257  ┆ 101.544976 ┆ 101.012551 ┆ 0.000856   ┆ -0.532425 │
# │ 00:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 119176.6 ┆ 0.010185   ┆ 101.012551 ┆ 102.046662 ┆ 0.000856   ┆ 1.03411   │
# │ 12:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ …          ┆ …        ┆ …        ┆ …          ┆ …          ┆ …          ┆ …          ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 121286.5 ┆ -0.025324  ┆ 118.837565 ┆ 115.86589  ┆ 0.000955   ┆ -2.971675 │
# │ 12:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 122825.7 ┆ 0.012611   ┆ 115.86589  ┆ 117.336299 ┆ 0.000955   ┆ 1.470409  │
# │ 00:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 123237.5 ┆ 0.003347   ┆ 117.336299 ┆ 117.729695 ┆ 0.000955   ┆ 0.393396  │
# │ 12:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 122672.9 ┆ 0.004592   ┆ 117.729695 ┆ 118.271544 ┆ -0.000955  ┆ 0.541849  │
# │ 00:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 121579.3 ┆ -0.008955  ┆ 118.271544 ┆ 117.217181 ┆ 0.000964   ┆ -1.054363 │
# │ 12:00:00   ┆          ┆          ┆            ┆            ┆            ┆            ┆           │
# └────────────┴──────────┴──────────┴────────────┴────────────┴────────────┴────────────┴───────────┘

# %% [markdown]
# ### Add Transaction Fees

# %%
trades = research.add_tx_fees(trades, data.binance.MAKER_FEE, data.binance.TAKER_FEE)
trades.select('datetime','entry_trade_value','exit_trade_value','tx_fee_maker','tx_fee_taker')
# Out:
# shape: (173, 5)
# ┌─────────────────────┬───────────────────┬──────────────────┬──────────────┬──────────────┐
# │ datetime            ┆ entry_trade_value ┆ exit_trade_value ┆ tx_fee_maker ┆ tx_fee_taker │
# │ ---                 ┆ ---               ┆ ---              ┆ ---          ┆ ---          │
# │ datetime[μs]        ┆ f64               ┆ f64              ┆ f64          ┆ f64          │
# ╞═════════════════════╪═══════════════════╪══════════════════╪══════════════╪══════════════╡
# │ 2025-07-15 12:00:00 ┆ 100.0             ┆ 100.536332       ┆ 0.040107     ┆ 0.060161     │
# │ 2025-07-16 00:00:00 ┆ 100.536332        ┆ 101.404401       ┆ 0.040388     ┆ 0.060582     │
# │ 2025-07-16 12:00:00 ┆ 101.404401        ┆ 101.544976       ┆ 0.04059      ┆ 0.060885     │
# │ 2025-07-17 00:00:00 ┆ 101.544976        ┆ 101.012551       ┆ 0.040512     ┆ 0.060767     │
# │ 2025-07-17 12:00:00 ┆ 101.012551        ┆ 102.046662       ┆ 0.040612     ┆ 0.060918     │
# │ …                   ┆ …                 ┆ …                ┆ …            ┆ …            │
# │ 2025-10-07 12:00:00 ┆ 118.837565        ┆ 115.86589        ┆ 0.046941     ┆ 0.070411     │
# │ 2025-10-08 00:00:00 ┆ 115.86589         ┆ 117.336299       ┆ 0.04664      ┆ 0.069961     │
# │ 2025-10-08 12:00:00 ┆ 117.336299        ┆ 117.729695       ┆ 0.047013     ┆ 0.07052      │
# │ 2025-10-09 00:00:00 ┆ 117.729695        ┆ 118.271544       ┆ 0.0472       ┆ 0.0708       │
# │ 2025-10-09 12:00:00 ┆ 118.271544        ┆ 117.217181       ┆ 0.047098     ┆ 0.070647     │
# └─────────────────────┴───────────────────┴──────────────────┴──────────────┴──────────────┘

# %% [markdown]
# ### Add Trade Net PnL

# %%
trades = trades.with_columns(
    (pl.col('trade_gross_pnl') - pl.col('tx_fee_taker')).alias('trade_net_taker_pnl')
)
trades.select('datetime','open','close','close_log_return','y_hat','entry_trade_value','exit_trade_value','trade_gross_pnl','trade_net_taker_pnl')
# Out:
# shape: (173, 9)
# ┌────────────┬──────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ close    ┆ close_log ┆ … ┆ entry_tra ┆ exit_trad ┆ trade_gro ┆ trade_net │
# │ ---        ┆ ---      ┆ ---      ┆ _return   ┆   ┆ de_value  ┆ e_value   ┆ ss_pnl    ┆ _taker_pn │
# │ datetime[μ ┆ f64      ┆ f64      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ l         │
# │ s]         ┆          ┆          ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---       │
# │            ┆          ┆          ┆           ┆   ┆           ┆           ┆           ┆ f64       │
# ╞════════════╪══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 117738.5 ┆ 0.005349  ┆ … ┆ 100.0     ┆ 100.53633 ┆ 0.536332  ┆ 0.476171  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 2         ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 118755.1 ┆ 0.008597  ┆ … ┆ 100.53633 ┆ 101.40440 ┆ 0.86807   ┆ 0.807488  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆ 2         ┆ 1         ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 118590.7 ┆ -0.001385 ┆ … ┆ 101.40440 ┆ 101.54497 ┆ 0.140575  ┆ 0.07969   │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆ 1         ┆ 6         ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 117968.9 ┆ -0.005257 ┆ … ┆ 101.54497 ┆ 101.01255 ┆ -0.532425 ┆ -0.593192 │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆ 6         ┆ 1         ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 119176.6 ┆ 0.010185  ┆ … ┆ 101.01255 ┆ 102.04666 ┆ 1.03411   ┆ 0.973193  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆ 1         ┆ 2         ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 121286.5 ┆ -0.025324 ┆ … ┆ 118.83756 ┆ 115.86589 ┆ -2.971675 ┆ -3.042086 │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆ 5         ┆           ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 122825.7 ┆ 0.012611  ┆ … ┆ 115.86589 ┆ 117.33629 ┆ 1.470409  ┆ 1.400448  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆           ┆ 9         ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 123237.5 ┆ 0.003347  ┆ … ┆ 117.33629 ┆ 117.72969 ┆ 0.393396  ┆ 0.322876  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆ 9         ┆ 5         ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 122672.9 ┆ -0.004592 ┆ … ┆ 117.72969 ┆ 118.27154 ┆ 0.541849  ┆ 0.471049  │
# │ 00:00:00   ┆          ┆          ┆           ┆   ┆ 5         ┆ 4         ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 121579.3 ┆ -0.008955 ┆ … ┆ 118.27154 ┆ 117.21718 ┆ -1.054363 ┆ -1.12501  │
# │ 12:00:00   ┆          ┆          ┆           ┆   ┆ 4         ┆ 1         ┆           ┆           │
# └────────────┴──────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Display Equity Curve (Compounding)

# %%
trades = research.add_equity_curve(trades, capital, 'trade_net_taker_pnl', 'taker')
research.plot_static_timeseries(trades, sym, 'equity_curve_taker', time_interval)

# %% [markdown]
# ### Calculate Total Net Return for Compounding Trade Sizing

# %%
compound_total_net_return = trades['equity_curve_taker'][-1] / capital - 1
compound_total_net_return
# Out:
# 0.05841440481350424

# %%
constant_sizing_net_return
# Out:
# 0.06391913937476579

# %%
np.round(compound_total_net_return - constant_sizing_net_return, 2)
# Out:
# np.float64(-0.01)

# %% [markdown]
# ## Key Strategy Decision #3: Leverage

# %%
# leverage is borrowing money to increase our profits

# %%
# in theory, we are multiplying our trade size to increase our returns
# we are not multiplying our trade returns
# just remember, it amplifies BOTH your profit and losses so it's important to have a postive expected value
# leverage only works when you have a high Sharpe model. The more risk you reduce, the more you reduce drawdowns and more leverage you can use

# %%
# key decision 3: should we use leverage? if so, how much? What's the sweet spot?
# It's not a golden utopia to multiplying profits, because it can easily wipe you out

# %%
leverage = 4
leverage * capital
# Out:
# 400

# %%
# trades = research.add_compounding_trades(trades, capital, leverage, maker_fee, taker_fee) 
# trades

# %%
trades = research.add_constant_trades(trades, capital, leverage, maker_fee, taker_fee) 
trades
# Out:
# shape: (173, 27)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ high     ┆ low      ┆ … ┆ equity_cur ┆ equity_cu ┆ tx_fee_ma ┆ tx_fee_ta │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ve_maker   ┆ rve_gross ┆ ker       ┆ ker       │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │ s]         ┆          ┆          ┆          ┆   ┆ f64        ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 118499.8 ┆ 115678.1 ┆ … ┆ 101.984897 ┆ 102.14532 ┆ 0.160429  ┆ 0.240644  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 6         ┆           ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 119299.9 ┆ 117017.1 ┆ … ┆ 105.277962 ┆ 105.59908 ┆ 0.160691  ┆ 0.241036  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 2         ┆           ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 120100.0 ┆ 118156.0 ┆ … ┆ 105.672363 ┆ 106.15359 ┆ 0.160111  ┆ 0.240166  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 4         ┆           ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 119216.4 ┆ 117663.6 ┆ … ┆ 103.415485 ┆ 104.05629 ┆ 0.159581  ┆ 0.239371  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 6         ┆           ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 120951.5 ┆ 117412.8 ┆ … ┆ 107.349644 ┆ 108.15127 ┆ 0.160819  ┆ 0.241228  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 4         ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ … ┆ 135.362885 ┆ 162.41536 ┆ 0.158     ┆ 0.236999  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 8         ┆           ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ … ┆ 140.278115 ┆ 167.49161 ┆ 0.161015  ┆ 0.241523  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 3         ┆           ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ … ┆ 141.458934 ┆ 168.8327  ┆ 0.160268  ┆ 0.240402  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ … ┆ 143.139559 ┆ 170.67369 ┆ 0.160368  ┆ 0.240552  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 4         ┆           ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ … ┆ 139.414367 ┆ 167.10778 ┆ 0.159287  ┆ 0.23893   │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆ 8         ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
trades['equity_curve_taker'][-1] / capital - 1
# Out:
# 0.2556765574990627

# %% [markdown]
# ## What if we increase to 8x leverage?

# %%
trades = research.add_constant_trades(trades, capital, 8, maker_fee, taker_fee)

# %%
trades['equity_curve_taker'][-1] / capital - 1
# Out:
# 0.5113531149981254

# %%
# reason for this huge return is the combination of model's edge, compounding and leverage
# this is possible on a small scale because we trading such small size that we are not moving markets around

# %% [markdown]
# ### Win Rate hasn't changed

# %%
trades.select((pl.col("trade_log_return") > 0).mean())
# Out:
# shape: (1, 1)
# ┌──────────────────┐
# │ trade_log_return │
# │ ---              │
# │ f64              │
# ╞══════════════════╡
# │ 0.531792         │
# └──────────────────┘

# %% [markdown]
# ### Factor Liquidation (price moves against us too much)

# %%
# Liquidation is when we go bust. If use too much leverage, then a small price change can wipe us out. 
# Leverage is a double edged sword. You can amplify profits, but too much leverage and you can wipe out all your money.

# %%
# Equity = Maintenance Margin
# calulcation differs from different exchanges

# %%
maintenance_margin = 0.005

def long_liquidation_price(p, l, mmr):
    return (p * l) / (l + 1 - mmr * l)

def short_liquidation_price(p, l, mmr):
    return (p * l) / (l - 1 + mmr * l)

# %% [markdown]
# ### How leverage affects long positions

# %%
long_liquidation_price(100, 2, maintenance_margin)
# Out:
# 66.8896321070234

# %%
long_liquidation_price(100, 4, maintenance_margin)
# Out:
# 80.32128514056224

# %%
long_liquidation_price(100, 10, maintenance_margin)
# Out:
# 91.32420091324201

# %%
long_liquidation_price(100, 50, maintenance_margin)
# Out:
# 98.52216748768473

# %% [markdown]
# ### How leverage affects short positions

# %%
short_liquidation_price(100, 2, maintenance_margin)
# Out:
# 198.01980198019803

# %%
short_liquidation_price(100, 4, maintenance_margin)
# Out:
# 132.4503311258278

# %%
short_liquidation_price(100, 10, maintenance_margin)
# Out:
# 110.49723756906076

# %%
short_liquidation_price(100, 60, maintenance_margin)
# Out:
# 101.18043844856662

# %% [markdown]
# ### Add Liquidation Prices

# %%
leverage
# Out:
# 4

# %%
trades = trades.with_columns(
    pl.when(pl.col("dir_signal") == 1)  # long position
      .then(
          (pl.col("open") * leverage)
          / (leverage + 1 - maintenance_margin * leverage)
      )
      .when(pl.col("dir_signal") == -1)  # short position
      .then(
          (pl.col("open") * leverage)
          / (leverage - 1 + maintenance_margin * leverage)
      )
      .otherwise(None)
      .alias("liquidation_price")
)
trades.select('datetime','open','high','low','close','liquidation_price','dir_signal')
# Out:
# shape: (173, 7)
# ┌─────────────────────┬──────────┬──────────┬──────────┬──────────┬───────────────────┬────────────┐
# │ datetime            ┆ open     ┆ high     ┆ low      ┆ close    ┆ liquidation_price ┆ dir_signal │
# │ ---                 ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---               ┆ ---        │
# │ datetime[μs]        ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64               ┆ f32        │
# ╞═════════════════════╪══════════╪══════════╪══════════╪══════════╪═══════════════════╪════════════╡
# │ 2025-07-15 12:00:00 ┆ 117110.4 ┆ 118499.8 ┆ 115678.1 ┆ 117738.5 ┆ 94064.578313      ┆ 1.0        │
# │ 2025-07-16 00:00:00 ┆ 117738.6 ┆ 119299.9 ┆ 117017.1 ┆ 118755.1 ┆ 94569.156627      ┆ 1.0        │
# │ 2025-07-16 12:00:00 ┆ 118755.1 ┆ 120100.0 ┆ 118156.0 ┆ 118590.7 ┆ 157291.523179     ┆ -1.0       │
# │ 2025-07-17 00:00:00 ┆ 118590.7 ┆ 119216.4 ┆ 117663.6 ┆ 117968.9 ┆ 95253.574297      ┆ 1.0        │
# │ 2025-07-17 12:00:00 ┆ 117968.8 ┆ 120951.5 ┆ 117412.8 ┆ 119176.6 ┆ 94754.056225      ┆ 1.0        │
# │ …                   ┆ …        ┆ …        ┆ …        ┆ …        ┆ …                 ┆ …          │
# │ 2025-10-07 12:00:00 ┆ 124397.1 ┆ 125098.0 ┆ 120516.0 ┆ 121286.5 ┆ 99917.349398      ┆ 1.0        │
# │ 2025-10-08 00:00:00 ┆ 121286.6 ┆ 123150.0 ┆ 121005.3 ┆ 122825.7 ┆ 97418.955823      ┆ 1.0        │
# │ 2025-10-08 12:00:00 ┆ 122825.8 ┆ 124170.6 ┆ 121607.8 ┆ 123237.5 ┆ 98655.261044      ┆ 1.0        │
# │ 2025-10-09 00:00:00 ┆ 123237.4 ┆ 123279.7 ┆ 121081.5 ┆ 122672.9 ┆ 163228.344371     ┆ -1.0       │
# │ 2025-10-09 12:00:00 ┆ 122673.0 ┆ 123740.1 ┆ 119572.8 ┆ 121579.3 ┆ 98532.53012       ┆ 1.0        │
# └─────────────────────┴──────────┴──────────┴──────────┴──────────┴───────────────────┴────────────┘

# %% [markdown]
# ### Add Liquidation Flag

# %%
trades = trades.with_columns([
    # Worst price based on direction
    pl.when(pl.col("dir_signal") == 1)
      .then(pl.col("low"))
      .otherwise(pl.col("high"))
      .alias("worst_price"),

    # Liquidation flag
    pl.when(
        (pl.col("dir_signal") == 1) & (pl.col("low") <= pl.col("liquidation_price"))
    )
    .then(True)
    .when(
        (pl.col("dir_signal") == -1) & (pl.col("high") >= pl.col("liquidation_price"))
    )
    .then(True)
    .otherwise(False)
    .alias("liquidated")
])
trades.select('datetime','open','low','high','close','dir_signal','worst_price','liquidation_price','liquidated')
# Out:
# shape: (173, 9)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open     ┆ low      ┆ high     ┆ … ┆ dir_signal ┆ worst_pri ┆ liquidati ┆ liquidate │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ---        ┆ ce        ┆ on_price  ┆ d         │
# │ datetime[μ ┆ f64      ┆ f64      ┆ f64      ┆   ┆ f32        ┆ ---       ┆ ---       ┆ ---       │
# │ s]         ┆          ┆          ┆          ┆   ┆            ┆ f64       ┆ f64       ┆ bool      │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-07-15 ┆ 117110.4 ┆ 115678.1 ┆ 118499.8 ┆ … ┆ 1.0        ┆ 115678.1  ┆ 94064.578 ┆ false     │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 313       ┆           │
# │ 2025-07-16 ┆ 117738.6 ┆ 117017.1 ┆ 119299.9 ┆ … ┆ 1.0        ┆ 117017.1  ┆ 94569.156 ┆ false     │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 627       ┆           │
# │ 2025-07-16 ┆ 118755.1 ┆ 118156.0 ┆ 120100.0 ┆ … ┆ -1.0       ┆ 120100.0  ┆ 157291.52 ┆ false     │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 3179      ┆           │
# │ 2025-07-17 ┆ 118590.7 ┆ 117663.6 ┆ 119216.4 ┆ … ┆ 1.0        ┆ 117663.6  ┆ 95253.574 ┆ false     │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 297       ┆           │
# │ 2025-07-17 ┆ 117968.8 ┆ 117412.8 ┆ 120951.5 ┆ … ┆ 1.0        ┆ 117412.8  ┆ 94754.056 ┆ false     │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 225       ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-10-07 ┆ 124397.1 ┆ 120516.0 ┆ 125098.0 ┆ … ┆ 1.0        ┆ 120516.0  ┆ 99917.349 ┆ false     │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 398       ┆           │
# │ 2025-10-08 ┆ 121286.6 ┆ 121005.3 ┆ 123150.0 ┆ … ┆ 1.0        ┆ 121005.3  ┆ 97418.955 ┆ false     │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 823       ┆           │
# │ 2025-10-08 ┆ 122825.8 ┆ 121607.8 ┆ 124170.6 ┆ … ┆ 1.0        ┆ 121607.8  ┆ 98655.261 ┆ false     │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 044       ┆           │
# │ 2025-10-09 ┆ 123237.4 ┆ 121081.5 ┆ 123279.7 ┆ … ┆ -1.0       ┆ 123279.7  ┆ 163228.34 ┆ false     │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 4371      ┆           │
# │ 2025-10-09 ┆ 122673.0 ┆ 119572.8 ┆ 123740.1 ┆ … ┆ 1.0        ┆ 119572.8  ┆ 98532.530 ┆ false     │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆ 12        ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Find Liquidated Trades

# %%
trades.filter(pl.col("liquidated") == True)
# Out:
# shape: (0, 30)
# ┌──────────────┬──────┬──────┬─────┬───┬──────────────┬─────────────────┬─────────────┬────────────┐
# │ datetime     ┆ open ┆ high ┆ low ┆ … ┆ tx_fee_taker ┆ liquidation_pri ┆ worst_price ┆ liquidated │
# │ ---          ┆ ---  ┆ ---  ┆ --- ┆   ┆ ---          ┆ ce              ┆ ---         ┆ ---        │
# │ datetime[μs] ┆ f64  ┆ f64  ┆ f64 ┆   ┆ f64          ┆ ---             ┆ f64         ┆ bool       │
# │              ┆      ┆      ┆     ┆   ┆              ┆ f64             ┆             ┆            │
# ╞══════════════╪══════╪══════╪═════╪═══╪══════════════╪═════════════════╪═════════════╪════════════╡
# └──────────────┴──────┴──────┴─────┴───┴──────────────┴─────────────────┴─────────────┴────────────┘

# %%
# third part is coding this all up and putting this all into action - where I am going to put this live with small amount of money

# topics we haven't covered - this is just a foundation to build upon
# alpha decay (also known as model drift) => where the prediction performance drifts => 
# market impact => we are not trading big sizes => if we were, we could potentially move markets against us
# funding fees/rebates
# slippage => we may not always get the best price, we may get executed at prices below top of the book (best bid/ask)
